# %% [markdown]
# # ProjectTerra.Framework Tasks Page

# %% [markdown]
# ### Launch test

# %%
# %%bash
#
# dotnet run --project /home/tsukimotox/Desktop/ProjectTerra/ProjectTerra.Game/ProjectTerra.Game.csproj
# Out:
# /home/tsukimotox/Desktop/ProjectTerra/ProjectTerra.Framework/Graphics/Renderer.cs(77,31): warning CS8602: Dereference of a possibly null reference. [/home/tsukimotox/Desktop/ProjectTerra/ProjectTerra.Framework/ProjectTerra.Framework.csproj]
# Input devices: Keyboard&Mouse
# [ProjectTerra.Framework.Platform:Window] Window successfully initialized!
# [ProjectTerra.Framework.Graphics:Shader] Using shader: 3
# [ProjectTerra.Framework.Graphics:TextureManager] Max texture size: 16384x16384
# [ProjectTerra.Framework.Graphics:TextureManager] Max texture units: 32
# New object is created: test
# Added object test to scene default
# New object is created: camera
# Added object camera to scene default
# Test scene loaded.
# (0, 0, 0.009765625, 0.009765625)
# [ProjectTerra.Framework.Platform:Host] Running on platform: Linux
# Rendering test!
# [ProjectTerra.Framework.Graphics:Shader] Using shader: 6
# Binding texture 1
# Rendering camera!
# ...
